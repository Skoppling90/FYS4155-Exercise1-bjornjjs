# %% [markdown]
# # Homework 1

# %% [markdown]
# Python instructions from tekst:

# %%
import numpy as np
from random import random, seed
x=np.random.rand(100,1)
y=5*x*x+0.1*np.random.randn(100,1)

# %% [markdown]
# Using own code

# %%
import numpy as np
from random import random, seed
import matplotlib.pyplot as plt
from sklearn import linear_model

x=np.random.rand(100,1)
y=5*x*x+0.1*np.random.randn(100,1)



# #############################################################################
# Compute prediction

xb = np.c_[np.ones((100,1)), x]
beta = np.linalg.inv(xb.T.dot(xb)).dot(xb.T).dot(y)
xnew = np.array([[0],[2]])
xbnew = np.c_[np.ones((2,1)), xnew]
ypredict = xbnew.dot(beta)


# #############################################################################
# Display results
plt.plot(xnew, ypredict, "r-") #r- lager en kontinuerlig "strek" av xnew og ypredict
plt.plot(x,y,'ro') 
plt.axis([0,2.0,0, 15.0]) #Setter aksene på plottet
plt.xlabel(r'$x$') #Setter navn på x-akse
plt.ylabel(r'$y$') #Setter navn på y-akse
plt.title(r'Linear Regression') #Setter navn på plottet
plt.show()

# %%
import numpy as np
from random import random, seed
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

x=np.random.rand(100,1)
y=5*x*x+0.1*np.random.randn(100,1)
linreg = LinearRegression()
linreg.fit(x,y)
xnew = np.array([[0],[2]])
ypredict = linreg.predict(xnew)

plt.plot(xnew, ypredict, "r-")
plt.plot(x, y ,'ro')
plt.axis([0,2.0,0, 15.0])
plt.xlabel(r'$x$')
plt.ylabel(r'$y$')
plt.title(r'Random numbers ')
plt.show()
